# %% [markdown]
# <a href="https://colab.research.google.com/github/drfperez/Python3_Jupyter_Notebook/blob/master/M1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ======================================================
# 🧮 VARIABLES - Tipus, assignació múltiple i conversions
# ======================================================

print("## VARIABLES ##")

# Tipus bàsics
nom = "Clara"             # str
edat = 25                 # int
altura = 1.68             # float
estudiant = True          # bool

print("Nom:", nom)
print("Edat:", edat)
print("Altura:", altura)
print("És estudiant?", estudiant)

# Assignació múltiple
a, b, c = 1, 2, 3
print("Assignació múltiple: a =", a, ", b =", b, ", c =", c)

# Canvi de tipus (casting)
edat_text = str(edat)      # int → str
altura_int = int(altura)   # float → int (trunca el decimal)

print("Edat com a text:", edat_text)
print("Altura com a enter:", altura_int)

# Tipus avançats
llista = [1, 2, 3]
diccionari = {"nom": nom, "edat": edat}
conjunt = set([1, 2, 2, 3])  # Elimina duplicats

print("Llista:", llista)
print("Diccionari:", diccionari)
print("Conjunt (sense duplicats):", conjunt)
print("-" * 60)

# ========================================================
# ➕ OPERADORS MATEMÀTICS - bàsics, avançats i aplicacions
# ========================================================

print("## OPERADORS MATEMÀTICS ##")

x = 12
y = 5

# Bàsics
print(f"Suma: {x} + {y} =", x + y)
print(f"Resta: {x} - {y} =", x - y)
print(f"Multiplicació: {x} * {y} =", x * y)
print(f"Divisió: {x} / {y} =", x / y)

# Avançats
print(f"Divisió sencera: {x} // {y} =", x // y)
print(f"Resta (mòdul): {x} % {y} =", x % y)
print(f"Potència: {x} ** {y} =", x ** y)

# Aplicació pràctica: calcular l’àrea d’un cercle
import math
radi = 3
area = math.pi * radi ** 2
print("Àrea d’un cercle amb radi 3:", area)
print("-" * 60)

# ========================================================
# 🧠 OPERADORS LÒGICS - comparació, combinació i aplicacions
# ========================================================

print("## OPERADORS LÒGICS ##")

nota = 8
assistencia = 90

# Comparació
print("nota > 5:", nota > 5)
print("assistencia >= 80:", assistencia >= 80)

# Combinació
aprovat = nota >= 5 and assistencia >= 75
excel·lent = nota >= 9 or assistencia == 100

print("Està aprovat?", aprovat)
print("És excel·lent?", excel·lent)

# Negació
print("No està aprovat?", not aprovat)

# Exemple pràctic
if nota >= 5 and assistencia >= 75:
    print("L’estudiant aprova.")
else:
    print("L’estudiant suspèn.")

# Ús de parèntesis per controlar prioritat
print("Exemple amb lògica combinada:", (nota >= 5 and assistencia >= 75) or nota == 10)
print("-" * 60)

# =======================================================
# 🎤 ENTRADA I SORTIDA DE DADES - tipus, validació i format
# =======================================================

print("## ENTRADA I SORTIDA ##")

# Entrada de dades
nom_usuari = input("Com et dius? ")
print(f"Hola, {nom_usuari}!")

# Entrada amb conversió a enter
try:
    edat = int(input("Quants anys tens? "))
    print("L’any que ve tindràs", edat + 1, "anys.")
except ValueError:
    print("⚠️ Si us plau, escriu un número enter per a l’edat.")

# Entrada amb conversió a float
try:
    pes = float(input("Quin és el teu pes en kg? "))
    print("Pes registrat:", pes, "kg")
except ValueError:
    print("⚠️ Si us plau, escriu un número decimal per al pes.")

# Sortida formatada
altura = 1.72
print(f"{nom_usuari}, mesures registrades: {altura} m d'altura i {pes:.1f} kg de pes.")
print("-" * 60)
# Out:
# ## VARIABLES ##
# Nom: Clara
# Edat: 25
# Altura: 1.68
# És estudiant? True
# Assignació múltiple: a = 1 , b = 2 , c = 3
# Edat com a text: 25
# Altura com a enter: 1
# Llista: [1, 2, 3]
# Diccionari: {'nom': 'Clara', 'edat': 25}
# Conjunt (sense duplicats): {1, 2, 3}
# ------------------------------------------------------------
# ## OPERADORS MATEMÀTICS ##
# Suma: 12 + 5 = 17
# Resta: 12 - 5 = 7
# Multiplicació: 12 * 5 = 60
# Divisió: 12 / 5 = 2.4
# Divisió sencera: 12 // 5 = 2
# Resta (mòdul): 12 % 5 = 2
# Potència: 12 ** 5 = 248832
# Àrea d’un cercle amb radi 3: 28.274333882308138
# ------------------------------------------------------------
# ## OPERADORS LÒGICS ##
# nota > 5: True
# assistencia >= 80: True
# Està aprovat? True
# És excel·lent? False
# No està aprovat? False
# L’estudiant aprova.
# Exemple amb lògica combinada: True
# ------------------------------------------------------------
# ## ENTRADA I SORTIDA ##
# Com et dius? Pio
# Hola, Pio!
# Quants anys tens? 12
# ...
